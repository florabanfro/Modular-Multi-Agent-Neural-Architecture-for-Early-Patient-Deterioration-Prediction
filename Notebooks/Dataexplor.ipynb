# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/triage.csv')  # Replace with your actual dataset path

# %%
df.isna().sum()
# Out:
# subject_id         0
# stay_id            0
# temperature       26
# heartrate         24
# resprate          23
# o2sat             24
# sbp               23
# dbp               23
# pain              21
# acuity            15
# chiefcomplaint     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   subject_id      222 non-null    int64
#  1   stay_id         222 non-null    int64
#  2   temperature     196 non-null    float64
#  3   heartrate       198 non-null    float64
#  4   resprate        199 non-null    float64
#  5   o2sat           198 non-null    float64
#  6   sbp             199 non-null    float64
#  7   dbp             199 non-null    float64
#  8   pain            201 non-null    str
#  9   acuity          207 non-null    float64
#  10  chiefcomplaint  222 non-null    str
# dtypes: float64(7), int64(2), str(2)
# memory usage: 19.2 KB

# %%
pd.reset_option('display.max_rows')  # Show all rows in the output
df["chiefcomplaint"].value_counts() # Display the value counts of the "chiefcomplaint" column
# Out:
# chiefcomplaint
# Abd pain                     5
# Chest pain                   5
# Altered mental status        4
# Dyspnea                      4
# HEAD BLEED                   3
#                             ..
# Depression, Anxiety          1
# L Leg pain, Weakness         1
# Dehydration, Nausea, Rash    1
# Abd pain, Transfer           1
# Back pain                    1
# Name: count, Length: 182, dtype: int64

# %%
df["subject_id"].to_string()
# Out:
# '0      10018328\n1      10020187\n2      10020187\n3      10012853\n4      10020740\n5      10039708\n6      10020306\n7      10019568\n8      10018081\n9      10018081\n10     10010867\n11     10021487\n12     10003046\n13     10017492\n14     10017492\n15     10018501\n16     10008454\n17     10026354\n18     10029291\n19     10027445\n20     10010471\n21     10023117\n22     10002495\n23     10031404\n24     10017492\n25     10026255\n26     10015931\n27     10038999\n28     10029291\n29     10023117\n30     10023117\n31     10014354\n32     10003400\n33     10004235\n34     10002930\n35     10002428\n36     10007928\n37     10020944\n38     10002428\n39     10026406\n40     10020740\n41     10036156\n42     10006053\n43     10006053\n44     10000032\n45     10019777\n46     10021312\n47     10007818\n48     10020740\n49     10021938\n50     10016742\n51     10019917\n52     10037975\n53     10002428\n54     10015931\n55     10021938\n56     10027445\n57     10015860\n58     1001
# ...
